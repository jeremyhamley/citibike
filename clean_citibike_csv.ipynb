# %%
import pandas as pd
from sqlalchemy import create_engine
import os
import glob

# %%
#Read in all CSVs to a dataframe using glob

citi_raw_df = pd.concat(map(pd.read_csv, glob.glob('bike_data/*.csv')))

# %%
#review raw data
citi_raw_df
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2014                                               6559
# 1   1/2/2014                                               9334
# 2   1/3/2014                                               1288
# 3   1/4/2014                                               2494
# 4   1/5/2014                                               2937
# ..       ...                                                ...
# 66    6/6/19                                              81323
# 67    6/7/19                                              82908
# 68    6/8/19                                              78074
# 69    6/9/19                                              73954
# 70   6/10/19                                              37019
#
#    Cumulative trips (since launch):  \
# 0                           6323722
# 1                           6333056
# 2                           6334344
# 3                           6336838
# ...

# %%
#create new dataframe with desired columns
citibike_df = citi_raw_df[['Date', 'Trips over the past 24-hours (midnight to 11:59pm)', 'Miles traveled today (midnight to 11:59 pm)', 'Miles traveled to date', 'Total Annual Members (All Time)', '24-Hour Passes Purchased (midnight to 11:59 pm)', '7-Day Passes Purchased (midnight to 11:59 pm)', '3-Day Passes Purchased (midnight to 11:59 pm)']].copy()
citibike_df
# Out:
#         Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0   1/1/2014                                               6559
# 1   1/2/2014                                               9334
# 2   1/3/2014                                               1288
# 3   1/4/2014                                               2494
# 4   1/5/2014                                               2937
# ..       ...                                                ...
# 66    6/6/19                                              81323
# 67    6/7/19                                              82908
# 68    6/8/19                                              78074
# 69    6/9/19                                              73954
# 70   6/10/19                                              37019
#
#     Miles traveled today (midnight to 11:59 pm) Miles traveled to date  \
# 0                                         9.254             11,243,581
# ...

# %%
#save merged data to csv
citibike_df.to_csv('merged_clean_citibike.csv',index=False)
